# %%
# 원본
# 카메라 앱 연동한 비디오 영상 프레임 캡쳐 
import cv2
import time
import os

# 얼굴 인식용 Haar Cascade 파일 경로
cascade_path = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'

# # Haar Cascade 분류기 생성
face_cascade = cv2.CascadeClassifier(cascade_path)

# 카메라 열기
camera = cv2.VideoCapture('/content/drive/MyDrive/Colab Notebooks/object_detectection_video/project2/IMG_0085.MOV')

# 프레임 이미지를 저장할 폴더 경로 (현재 작업 디렉토리 기준)
output_folder = 'frames'
output_path = os.path.join(os.getcwd(), output_folder)
os.makedirs(output_path, exist_ok=True)

# 캡처할 시간 (초)
capture_duration = 10

# 저장할 최대 프레임 개수
max_frames = 100

start_time = time.time()  # 동영상 촬영 시작 시간
frame_index = 0  # 프레임 인덱스 초기화

while True:
    # 프레임 읽기
    ret, frame = camera.read()

    # 프레임 읽기에 실패하면 반복 종료
    if not ret:
        break

    # 그레이스케일 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 얼굴 인식
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30))

    # 얼굴에 사각형 표시 및 텍스트 추가
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        text = f'Turn your face sideways {frame_index}'  # 텍스트 내용 설정
        cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # 카메라 영상 표시
    # cv2.imshow("Camera", frame)

    # 동영상 프레임 저장
    elapsed_time = time.time() - start_time
    if elapsed_time <= capture_duration and frame_index < max_frames:
        image_path = os.path.join(output_path, f'frame_{frame_index}.jpg')
        cv2.imwrite(image_path, frame)
        frame_index += 1
    else:
        break

    # 'q' 키를 누르면 반복 종료
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    # 10ms 딜레이
    time.sleep(0.01)  # 0.01초(10ms) 딜레이

# 카메라 닫기
camera.release()


# 윈도우 닫기
cv2.destroyAllWindows()

print(f'동영상 촬영이 완료되었습니다. 총 {frame_index}개의 프레임이 저장되었습니다.')
# Out:
# 동영상 촬영이 완료되었습니다. 총 16개의 프레임이 저장되었습니다.

# %%
# 수정본1
# 비디오 영상 프레임 캡쳐 
import cv2
import time
import os

# 얼굴 인식용 Haar Cascade 파일 경로
cascade_path = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'

# Haar Cascade 분류기 생성
face_cascade = cv2.CascadeClassifier(cascade_path)

# 영상 업로드
video_path = '/content/drive/MyDrive/project2_Object_Detection_YOLO/IMG_8351_1.mov'  # 비디오 파일 경로
camera = cv2.VideoCapture(video_path)

# 프레임 이미지를 저장할 폴더 경로 (현재 작업 디렉토리 기준)
output_folder = '/content/drive/MyDrive/project2_Object_Detection_YOLO/data_image'
output_path = os.path.join(os.getcwd(), output_folder)
os.makedirs(output_path, exist_ok=True)

# 캡처할 시간 (초)
capture_duration = 300

# 저장할 최대 프레임 개수
max_frames = 100

start_time = time.time()  # 동영상 촬영 시작 시간
frame_index = 0  # 프레임 인덱스 초기화

while True:
    # 프레임 읽기
    ret, frame = camera.read()

    # 프레임 읽기에 실패하면 반복 종료
    if not ret:
        break

    # 그레이스케일 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 얼굴 인식
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30))

    # 얼굴에 사각형 표시 및 텍스트 추가
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        text = f'Turn your face sideways {frame_index}'  # 텍스트 내용 설정
        cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # 동영상 프레임 저장
    elapsed_time = time.time() - start_time
    if elapsed_time <= capture_duration and frame_index < max_frames:
        image_path = os.path.join(output_path, f'frame_{frame_index}.jpg')
        cv2.imwrite(image_path, frame)
        frame_index += 1
    else:
        break

    # 10ms 딜레이
    time.sleep(0.01)  # 0.01초(10ms) 딜레이

# 카메라 닫기
camera.release()

print(f'비디오 프레임 캡처가 완료되었습니다. 총 {frame_index}개의 프레임이 저장되었습니다.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-aa9aa6775827> in <cell line: 31>()
#      59
#      60     # 10ms 딜레이
# ---> 61     time.sleep(10)  # 10초 딜레이
#      62
#      63 # 카메라 닫기
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 수정본2
# 비디오 영상 프레임 캡처 
import cv2
import time
import os

# 얼굴 인식용 Haar Cascade 파일 경로
cascade_path = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'

# Haar Cascade 분류기 생성
face_cascade = cv2.CascadeClassifier(cascade_path)

# 영상 업로드
video_path = '/content/drive/MyDrive/project2_Object_Detection_YOLO/IMG_8351_1.mov'  # 비디오 파일 경로
camera = cv2.VideoCapture(video_path)

# 프레임 이미지를 저장할 폴더 경로 (현재 작업 디렉토리 기준)
output_folder = '/content/drive/MyDrive/project2_Object_Detection_YOLO/data_image'
output_path = os.path.join(os.getcwd(), output_folder)
os.makedirs(output_path, exist_ok=True)

# 캡처할 시간 간격 (초)
capture_interval = 10

# 저장할 최대 프레임 개수
max_frames = 100

start_time = time.time()  # 동영상 촬영 시작 시간
frame_index = 0  # 프레임 인덱스 초기화

while True:
    # 프레임 읽기
    ret, frame = camera.read()

    # 프레임 읽기에 실패하면 반복 종료
    if not ret:
        break

    # 그레이스케일 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 얼굴 인식
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30))

    # 얼굴에 사각형 표시 및 텍스트 추가
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        text = f'face {frame_index}'  # 텍스트 내용 설정
        cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # 동영상 프레임 저장
    elapsed_time = time.time() - start_time
    if elapsed_time >= capture_interval and frame_index < max_frames:
        image_path = os.path.join(output_path, f'frame_{frame_index}.jpg')
        cv2.imwrite(image_path, frame)
        frame_index += 1
        start_time = time.time()+capture_interval  # 다음 캡처 시작 시간 업데이트

    # 10ms 딜레이
    time.sleep(capture_interval)  # 0.01초(10ms) 딜레이

# 카메라 닫기
camera.release()

print(f'비디오 프레임 캡처가 완료되었습니다. 총 {frame_index}개의 프레임이 저장되었습니다.')

# In this modified code, the start_time is updated using time.time() instead of adding the capture interval. 
# This ensures that the capture interval remains consistent regardless of any delays in the loop execution.
# By updating the start_time to the current time, you capture frames every 10 seconds accurately.

# %%
# 수정본3
# 비디오 영상 프레임 캡처 
import cv2
import time
import os

# 얼굴 인식용 Haar Cascade 파일 경로
cascade_path = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'

# Haar Cascade 분류기 생성
face_cascade = cv2.CascadeClassifier(cascade_path)

# 영상 업로드
video_path = '/content/drive/MyDrive/project2_Object_Detection_YOLO/IMG_8351_1.mov'  # 비디오 파일 경로
camera = cv2.VideoCapture(video_path)

# 프레임 이미지를 저장할 폴더 경로 (현재 작업 디렉토리 기준)
output_folder = '/content/drive/MyDrive/project2_Object_Detection_YOLO/data_image'
output_path = os.path.join(os.getcwd(), output_folder)
os.makedirs(output_path, exist_ok=True)

# 캡처할 시간 간격 (초)
capture_interval = 10

# 저장할 최대 프레임 개수
max_frames = 100

fps = camera.get(cv2.CAP_PROP_FPS)  # 비디오의 FPS (Frame Per Second) 가져오기
capture_interval_frames = int(fps * capture_interval)  # 시간 간격을 프레임으로 변환

start_time = time.time()  # 동영상 촬영 시작 시간
frame_index = 0  # 프레임 인덱스 초기화

while True:
    # 프레임 읽기
    ret, frame = camera.read()

    # 프레임 읽기에 실패하면 반복 종료
    if not ret:
        break

    # 그레이스케일 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 얼굴 인식
    # faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30))

    # # 얼굴에 사각형 표시 및 텍스트 추가
    # for (x, y, w, h) in faces:
    #     cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    #     text = f'face {frame_index}'  # 텍스트 내용 설정
    #     cv2.putText(frame, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # 동영상 프레임 저장
    if frame_index % capture_interval_frames == 0 and frame_index < max_frames:
        image_path = os.path.join(output_path, f'frame_{frame_index}.jpg')
        cv2.imwrite(image_path, frame)
        frame_index += 1

    # 프레임 인덱스 증가
    frame_index += 1

# 카메라 닫기
camera.release()

print(f'비디오 프레임 캡처가 완료되었습니다. 총 {frame_index}개의 프레임이 저장되었습니다.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-cd2b1f49787e> in <cell line: 34>()
#      34 while True:
#      35     # 프레임 읽기
# ---> 36     ret, frame = camera.read()
#      37
#      38     # 프레임 읽기에 실패하면 반복 종료
#
# KeyboardInterrupt:

# %%
# 최종1
# 비디오 영상 프레임 캡처 
import cv2
import time
import os

# 영상 업로드
video_path = '/content/drive/MyDrive/project2_Object_Detection_YOLO/IMG_8351_1.mov'  # 비디오 파일 경로
camera = cv2.VideoCapture(video_path)

# 프레임 이미지를 저장할 폴더 경로
output_folder = '/content/drive/MyDrive/project2_Object_Detection_YOLO/data_image'
os.makedirs(output_folder, exist_ok=True)

# 캡처할 시간 간격 (초)
capture_interval = 10

# 저장할 최대 프레임 개수
max_frames = 30

start_time = time.time()  # 동영상 촬영 시작 시간
frame_index = 0  # 프레임 인덱스 초기화

while True:
    # 프레임 읽기
    ret, frame = camera.read()

    # 프레임 읽기에 실패하면 반복 종료
    if not ret:
        break

    # 동영상 프레임 저장
    elapsed_time = time.time() - start_time
    if elapsed_time >= capture_interval and frame_index < max_frames:
        image_path = os.path.join(output_folder, f'frame_{frame_index}.jpg')
        cv2.imwrite(image_path, frame)
        frame_index += 1
        start_time += capture_interval  # 다음 캡처 시작 시간 업데이트

# 카메라 닫기
camera.release()

print(f'비디오 프레임 캡처가 완료되었습니다. 총 {frame_index}개의 프레임이 저장되었습니다.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9a95cc92e5e2> in <cell line: 22>()
#      22 while True:
#      23     # 프레임 읽기
# ---> 24     ret, frame = camera.read()
#      25
#      26     # 프레임 읽기에 실패하면 반복 종료
#
# KeyboardInterrupt:

# %%
# 최종2-3
# 비디오 영상 프레임 캡처
import cv2
import time
import os

# 영상 업로드
video_path = '/content/drive/MyDrive/project2_Object_Detection_YOLO/IMG_8351_3.mov'  # 비디오 파일 경로
camera = cv2.VideoCapture(video_path)

# 프레임 이미지를 저장할 폴더 경로
output_folder = '/content/drive/MyDrive/project2_Object_Detection_YOLO/data_image3'
os.makedirs(output_folder, exist_ok=True)

# 캡처할 시간 간격 (초)
capture_interval = 30

# 저장할 최대 프레임 개수
max_frames = 100

start_time = time.time()  # 동영상 촬영 시작 시간
frame_index = 0  # 프레임 인덱스 초기화

while True:
    # 프레임 읽기
    ret, frame = camera.read()

    # 프레임 읽기에 실패하거나 최대 프레임 개수에 도달하면 반복 종료
    if not ret or frame_index >= max_frames:
        break

    # 동영상 프레임 저장
    elapsed_time = time.time() - start_time
    if elapsed_time >= capture_interval:
        image_path = os.path.join(output_folder, f'frame_{frame_index}.jpg')
        cv2.imwrite(image_path, frame)
        frame_index += 1
        start_time += capture_interval  # 다음 캡처 시작 시간 업데이트

# 카메라 닫기
camera.release()

print(f'비디오 프레임 캡처가 완료되었습니다. 총 {frame_index}개의 프레임이 저장되었습니다.')
# Out:
# 비디오 프레임 캡처가 완료되었습니다. 총 100개의 프레임이 저장되었습니다.

# %%
# 최종2-1
# 비디오 영상 프레임 캡처
import cv2
import time
import os

# 영상 업로드
video_path = '/content/drive/MyDrive/project2_Object_Detection_YOLO/IMG_8351_1.mov'  # 비디오 파일 경로
camera = cv2.VideoCapture(video_path)

# 프레임 이미지를 저장할 폴더 경로
output_folder = '/content/drive/MyDrive/project2_Object_Detection_YOLO/data_image'
os.makedirs(output_folder, exist_ok=True)

# 캡처할 시간 간격 (초)
capture_interval = 30

# 저장할 최대 프레임 개수
max_frames = 100

start_time = time.time()  # 동영상 촬영 시작 시간
frame_index = 0  # 프레임 인덱스 초기화

while True:
    # 프레임 읽기
    ret, frame = camera.read()

    # 프레임 읽기에 실패하거나 최대 프레임 개수에 도달하면 반복 종료
    if not ret or frame_index >= max_frames:
        break

    # 동영상 프레임 저장
    elapsed_time = time.time() - start_time
    if elapsed_time >= capture_interval:
        image_path = os.path.join(output_folder, f'frame_{frame_index}.jpg')
        cv2.imwrite(image_path, frame)
        frame_index += 1
        start_time += capture_interval  # 다음 캡처 시작 시간 업데이트

# 카메라 닫기
camera.release()

print(f'비디오 프레임 캡처가 완료되었습니다. 총 {frame_index}개의 프레임이 저장되었습니다.')
# Out:
# 비디오 프레임 캡처가 완료되었습니다. 총 51개의 프레임이 저장되었습니다.
